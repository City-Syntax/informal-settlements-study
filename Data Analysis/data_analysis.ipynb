# %% [markdown]
# # Research Project: Cooling Interventions for Informal Settlements in Bihar, India
#
# ## Project Overview
#
# This research project focuses on studying cooling interventions for informal settlements and slums in Bihar, India, particularly for structures made of scrap materials. The primary objectives are:
#
# 1. Assess the effectiveness of two cooling interventions: Radiant Barrier Foils (RBFs) and Mylar Emergency Blankets (MEBs)
# 2. Collect temperature and humidity data using data loggers in various houses across different settlements
# 3. Compare the effectiveness of interventions in shaded vs. non-shaded structures
# 4. Analyze the impact of these interventions on indoor temperatures during hot summer conditions
#
# ## Methodology
#
# 1. Place data loggers in multiple settlements:
#    - Rainbow Field Settlements
#    - Sports Complex Settlements
#    - Control group near a Petrol Pump
# 2. Collect baseline data for 15 days before implementing interventions
# 3. Implement RBFs and MEBs in different houses
# 4. Collect post-intervention data to compare with baseline readings
#
# The project aims to provide insights into effective, low-cost cooling solutions for informal settlements in hot climates, potentially improving living conditions for residents in these areas.
#
# ## Logger Placement
#
# Loggers in Rainbow Field settlements:
#
# | has_shade | logger | intervention |
# |-----------|--------|------------|
# | false     | U-15   | RBF        |
# | false     | U-14   | RBF        |
# | true      | U-13   | RBF        |
# | false     | U-12   | MEB        |
# | false     | U-11   | RBF        |
# | false     | U-09   | RBF        |
# | false     | U-08   | MEB        |
# | false     | U-06   | MEB        |
# | true      | U-05   | MEB        |
# | false     | U-04   | MEB        |
# | true      | U-03   | RBF        |
# | false     | R-14   | CONTROL    |
# | true      | R-13   | CONTROL    |
# | false     | R-12   | CONTROL    |
# | false     | R-11   | CONTROL    |
# | true      | R-10   | CONTROL    |
# | false     | R-09   | CONTROL    |
#
# We have more Loggers in Sports Complex settelements:
#
# | has_shade | logger | intervention |
# |-----------|--------|------------|
# | true      | U-38   | RBF        |
# | true      | U-37   | RBF        |
# | true      | U-36   | RBF        |
# | true      | U-35   | CONTROL    |
# | true      | U-34   | CONTROL    |
# | true      | U-33   | RBF        |
# | true      | U-32   | RBF        |
# | true      | U-31   | MEB        |
# | false     | U-29   | MEB        |
# | false     | U-28   | MEB        |
# | false     | U-25   | MEB        |
# | true      | U-23   | RBF        |
# | true      | U-22   | RBF        |
# | true      | U-21   | MEB        |
# | true      | U-20   | MEB        |
# | true      | U-19   | MEB        |
# | false     | U-18   | RBF        |
# | true      | U-17   | RBF        |
# | false     | U-16   | RBF        |
# | true      | R-18   | CONTROL    |
# | false     | R-17   | CONTROL    |
# | true      | R-16   | CONTROL    |
# | true      | R-15   | CONTROL    |
# | false     | R-08   | CONTROL    |
# | false     | R-07   | CONTROL    |
# | false     | R-06   | CONTROL    |
# | false     | R-05   | CONTROL    |
# | true      | R-04   | CONTROL    |
# | false     | R-03   | RBF        |
# | false     | R-02   | CONTROL    |
# | false     | R-01   | CONTROL    |
#
# ## Data Collection
#
# ### Data Loggers
#
# Two types of data loggers were used:
# - U-series (U-01 to U-40)
# - R-series (R-01 to R-20)
#
# #### Data Format
#
# U-series loggers:
# ```
# Date,Time,Temperature_Celsius(℃),Relative_Humidity(%),DPT(℃),VPD(kPa),Abs Humidity(g/m³)
# 2024-07-09,21:26,32.4,75,27.4,1.22,25.86
# 2024-07-09,21:27,32.5,75,27.5,1.22,26.0
# 2024-07-09,21:28,32.6,75,27.6,1.23,26.14
# ```
#
# R-series loggers:
# ```
# Date,Time,Temperature(C),Humidity(%RH)
# 2024-07-20,14:54,32.57,67.06
# 2024-07-20,14:55,32.41,66.16
# 2024-07-20,14:56,32.24,65.25
# 2024-07-20,14:57,32.08,64.35
# ```
#
# ### Environmental Data
#
# Environmental data from a nearby weather station is collected hourly:
# ```
# Date,Time,name,temp,feelslike,dew,humidity,precip,precipprob,preciptype,snow,snowdepth,windgust,windspeed,winddir,sealevelpressure,cloudcover,visibility,solarradiation,solarenergy,uvindex,severerisk,conditions,icon,stations
# 2024-06-01,00:00,"Kankarbagh, Patna",31.0,44.3,29.0,89.14,0.0,0.0,,0,0,33.5,18.4,100.0,1000.0,27.0,3.0,0,0.0,0,15,Partially cloudy,partly-cloudy-night,"VEPT,42492099999"
# 2024-06-01,01:00,"Kankarbagh, Patna",31.0,44.3,29.0,89.14,0.0,0.0,,0,0,34.2,20.5,100.0,1000.0,0.0,3.0,0,0.0,0,15,Clear,clear-night,"VEPT,42492099999"
# ```
# Even though the environmental data is for every hour, There is interpolated data for every minute in the masterdataframe CSV file.
#
# ### Master Dataframe
#
# A consolidated CSV file contains minute-by-minute data for all loggers and interpolated environmental data:
# ```
# DateTime,R-01,R-02,R-04,R-05,R-06,R-07,R-08,R-09,R-10,R-11,R-12,R-14,R-15,R-16,R-17,R-20,U-03,U-04,U-05,U-08,U-09,U-11,U-12,U-13,U-14,U-15,U-16,U-17,U-18,U-19,U-20,U-21,U-22,U-23,U-25,U-26,U-28,U-29,U-31,U-32,U-33,U-34,U-36,U-37,U-38,Env_Temperature
# 2024-07-22 17:26:00,35.64,48.46,34.3,36.25,35.51,36.66,40.44,40.04,35.99,40.14,34.54,37.22,34.73,37.71,39.48,38.78,40.8,37.5,37.3,36.1,36.8,34.8,29.7,35.3,36.4,35.7,,36.4,,34.5,35.0,35.0,34.1,35.8,37.6,,37.5,38.3,34.8,32.6,33.4,,33.4,33.0,32.7,33.943333333333335
# 2024-07-22 17:27:00,35.64,48.54,34.34,36.27,35.55,36.63,40.47,40.06,35.96,40.19,34.52,37.2,34.75,37.77,39.43,38.8,40.8,37.7,37.3,36.2,36.8,34.8,29.7,35.3,36.4,35.7,,36.3,,34.5,35.0,35.0,34.1,35.8,37.8,,37.4,38.5,34.8,32.6,33.4,,33.4,33.0,32.7,33.945
# 2024-07-22 17:28:00,35.66,48.63,34.38,36.3,35.59,36.6,40.51,40.09,35.93,40.08,34.5,37.17,34.77,37.83,39.37,38.82,40.8,37.9,37.3,36.3,36.9,34.8,29.7,35.3,36.4,35.7,,36.3,,34.5,35.0,35.1,34.2,35.8,38.0,,37.3,38.7,34.8,32.6,33.3,,33.4,33.0,32.7,33.946666666666665
# ```
#
# ## Data Analysis Considerations
#
# All the loggers on one start date but due to some issues some loggers start recording data from a later date. The earliest loggers start recording from Jun 4 but some started much later after it due to some data recording issues.
#
# 1. Logger start dates vary due to recording issues
# 2. Intervention implementation time and dates:
#    - Rainbow Field Settlement: July 15th (data valid from July 16th 00:00)
#    - Sports Complex Settlement: July 16th-19th (data valid from July 20th 00:00)
# 3. Last valid data point: August 5th 23:59 / August 6th 00:00
# 4. Environmental factors:
#    - Rain occurred during intervention implementation
#    - Weather stabilized after a week with occasional light showers
# 5. Potential analysis approach: Subtract environmental data from logger data to account for weather variations
#
# ## Logger Classifications
#
# - Shaded loggers: `['U-13', 'U-05', 'U-03', 'R-13', 'R-10', 'U-38', 'U-37', 'U-36', 'U-35', 'U-34', 'U-33', 'U-32', 'U-31', 'U-23', 'U-22', 'U-21', 'U-20', 'U-19', 'U-17', 'R-18', 'R-16', 'R-15', 'R-04']`
# - Unshaded loggers: `['U-15', 'U-14', 'U-12', 'U-11', 'U-09', 'U-08', 'U-06', 'U-04', 'R-14', 'R-12', 'R-11', 'R-09', 'U-29', 'U-28', 'U-25', 'U-18', 'U-16', 'R-17', 'R-08', 'R-07', 'R-06', 'R-05', 'R-03', 'R-02', 'R-01']`
# - MEB interventions: `['U-12', 'U-08', 'U-06', 'U-05', 'U-04', 'U-31', 'U-29', 'U-28', 'U-25', 'U-21', 'U-20', 'U-19']`
# - RBF interventions: `['U-15', 'U-14', 'U-13', 'U-11', 'U-09', 'U-03', 'U-38', 'U-37', 'U-36', 'U-33', 'U-32', 'U-23', 'U-22', 'U-18', 'U-17', 'U-16', 'R-03']`
# - Control interventions: `['R-14', 'R-13', 'R-12', 'R-11', 'R-10', 'R-09', 'U-35', 'U-34', 'R-18', 'R-17', 'R-16', 'R-15', 'R-08', 'R-07', 'R-06', 'R-05', 'R-04', 'R-02', 'R-01']`
#
# ## File Structure
#
# ```
# Data Analysis
# ├── Python Files.py
# ├── Environmental Data.csv
# ├── masterdataframe.csv
# └── Cleaned Data
#     └── [U and R data files]
# ```
#
# ## Available Loggers
#
# - U Loggers: `['U-03', 'U-04', 'U-05', 'U-08', 'U-09', 'U-11', 'U-12', 'U-13', 'U-14', 'U-15', 'U-16', 'U-17', 'U-18', 'U-19', 'U-20', 'U-21', 'U-22', 'U-23', 'U-25', 'U-26', 'U-28', 'U-29', 'U-31', 'U-32', 'U-33', 'U-34', 'U-36', 'U-37', 'U-38']`
# - R Loggers: `['R-01', 'R-02', 'R-04', 'R-05', 'R-06', 'R-07', 'R-08', 'R-09', 'R-10', 'R-11', 'R-12', 'R-14', 'R-15', 'R-16', 'R-17', 'R-20']`
#
# This research aims to provide insights into effective, low-cost cooling solutions for informal settlements in hot climates, potentially improving living conditions for residents in these areas.

# %% [markdown]
# ### This following script processes logger data files, detecting their encoding and cleans the logger data.
#
# It includes functions to:
# - Detect file encoding to handle potential Unicode errors.
# - Clean and reformat U logger data.
# - Clean and reformat R logger data.
# - Process all logger files in a specified directory, clean them, and save the cleaned data to a new folder.

# %%
import os
import pandas as pd
import chardet

def detect_encoding(file_path):
    """Detect the file encoding to handle potential unicode errors."""
    with open(file_path, 'rb') as f:
        result = chardet.detect(f.read())
    return result['encoding']

def clean_u_logger_data(file_path):
    """Clean and reformat U logger data."""
    encoding = detect_encoding(file_path)
    df = pd.read_csv(file_path, encoding=encoding)

    df['Date'] = pd.to_datetime(df['Date'], format="%b %d, %Y %I:%M %p")
    df['Time'] = df['Date'].dt.strftime('%H:%M')
    df['Date'] = df['Date'].dt.date

    columns = ['Date', 'Time'] + [col for col in df.columns if col not in ['Date', 'Time']]
    df = df[columns]

    return df

def clean_r_logger_data(file_path):
    """Clean and reformat R logger data."""
    encoding = detect_encoding(file_path)
    df = pd.read_csv(file_path, sep='\t', encoding=encoding, skiprows=1)

    df['Time'] = pd.to_datetime(df['Time'], format="%Y-%m-%d %H:%M:%S")
    df['Date'] = df['Time'].dt.date
    df['Time'] = df['Time'].dt.strftime('%H:%M')

    columns = ['Date', 'Time', 'Temperature(C)', 'Humidity(%RH)']
    df = df[columns]

    return df

def process_loggers(data_dir):
    """Process all loggers and save cleaned data to a new folder."""
    u_loggers = []
    r_loggers = []

    cleaned_data_dir = os.path.join(os.path.dirname(data_dir), 'Cleaned_Data')
    os.makedirs(cleaned_data_dir, exist_ok=True)

    for file_name in os.listdir(data_dir):
        if file_name.endswith('_data.csv'):
            logger_id = file_name.split('_')[0]
            file_path = os.path.join(data_dir, file_name)
            cleaned_file_path = os.path.join(cleaned_data_dir, file_name)

            if file_name.startswith('U-'):
                u_loggers.append(logger_id)
                cleaned_df = clean_u_logger_data(file_path)
            elif file_name.startswith('R-'):
                r_loggers.append(logger_id)
                cleaned_df = clean_r_logger_data(file_path)
            else:
                continue

            cleaned_df.to_csv(cleaned_file_path, index=False, encoding='utf-8-sig')
    
    return u_loggers, r_loggers

if __name__ == "__main__":
    data_dir = './Loggers Data'
    u_loggers, r_loggers = process_loggers(data_dir)
    
    print("U Loggers available:", u_loggers)
    print("R Loggers available:", r_loggers)

# %% [markdown]
# ### This following script reformats the environment data file.
#
# It includes functions to:
# - Clean the date and time columns in a more readable format.

# %%
import pandas as pd
import os

def clean_environmental_data(file_path):
    """Clean and reformat Environmental Data."""
    df = pd.read_csv(file_path)

    df['datetime'] = pd.to_datetime(df['datetime'])

    df['Date'] = df['datetime'].dt.date
    df['Time'] = df['datetime'].dt.strftime('%H:%M')

    df = df.drop(columns=['datetime'])

    columns = ['Date', 'Time'] + [col for col in df.columns if col not in ['Date', 'Time']]
    df = df[columns]

    return df

if __name__ == "__main__":
    base_dir = os.path.dirname(os.path.abspath(__file__))
    file_path = os.path.join(base_dir, 'Environmental Data.csv')
    
    cleaned_df = clean_environmental_data(file_path)
    
    cleaned_df.to_csv(file_path, index=False)
    
    print("Environmental Data cleaned and saved successfully.")

# %% [markdown]
# ### This following script combines the temperature info from the environmental data and all the logger data files.
#
# 1. **Reads logger data** from CSV files, combining 'Date' and 'Time' columns into a 'DateTime' index.
# 2. **Aggregates logger data** into a master DataFrame with a one-minute frequency.
# 3. **Reads and processes environmental data**, resampling and interpolating it to match the logger data frequency.
# 4. **Combines logger and environmental data** into the master DataFrame.
# 5. **Saves the master DataFrame** to a CSV file.
# 6. **Prints summary information** including the first few rows, shape, NaN counts, and first non-NaN entries for each logger.
#
# Produces `master_dataframe.csv` file:

# %%
import pandas as pd
import numpy as np
import os
import glob
import chardet

def detect_encoding(file_path):
    with open(file_path, 'rb') as file:
        raw_data = file.read()
    return chardet.detect(raw_data)['encoding']

def read_logger_data(file_path):
    encoding = detect_encoding(file_path)
    df = pd.read_csv(file_path, encoding=encoding)
    df['DateTime'] = pd.to_datetime(df['Date'] + ' ' + df['Time'])
    return df.set_index('DateTime')[['Temperature_Celsius(℃)']] if 'Temperature_Celsius(℃)' in df.columns else df.set_index('DateTime')[['Temperature(C)']]

logger_files = glob.glob('Cleaned Data/*.csv')
logger_dfs = {}

for file in logger_files:
    logger_id = os.path.basename(file).split('_')[0]
    logger_dfs[logger_id] = read_logger_data(file)

start_date = min(df.index.min() for df in logger_dfs.values())
end_date = max(df.index.max() for df in logger_dfs.values())
master_index = pd.date_range(start=start_date, end=end_date, freq='T')

master_df = pd.DataFrame(index=master_index)

for logger_id, df in logger_dfs.items():
    master_df[f'{logger_id}'] = df.reindex(master_index)

env_data = pd.read_csv('Environmental Data.csv')
env_data['DateTime'] = pd.to_datetime(env_data['Date'] + ' ' + env_data['Time'])
env_data = env_data.set_index('DateTime')

env_data_resampled = env_data.resample('T').interpolate()

master_df['Env_Temperature'] = env_data_resampled['temp']

master_df.to_csv('master_dataframe.csv')

print("Master dataframe created and saved as 'master_dataframe.csv'")
print(master_df.head())
print(f"Shape of master dataframe: {master_df.shape}")

nan_counts = master_df.isna().sum()
print("\nNumber of NaN values in each column:")
print(nan_counts)

print("\nFirst non-NaN entry for each logger:")
for column in master_df.columns:
    first_valid = master_df[column].first_valid_index()
    if first_valid is not None:
        print(f"{column}: {first_valid}")
    else:
        print(f"{column}: All values are NaN")

# %% [markdown]
# ### The following script analyzes the master data frame to make a 3D countour plot of the temperature data.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

master_df = pd.read_csv('master_dataframe.csv', parse_dates=['DateTime'])

long_df = pd.melt(master_df, id_vars=['DateTime'], var_name='Logger', value_name='Temperature')

long_df['Temperature'].fillna(0, inplace=True)

long_df['Logger_numeric'] = pd.factorize(long_df['Logger'])[0]

long_df['DateTime_numeric'] = long_df['DateTime'].apply(lambda x: x.toordinal())

X = long_df['DateTime_numeric']
Y = long_df['Logger_numeric']
Z = long_df['Temperature']

fig = plt.figure(figsize=(16, 10))
ax = fig.add_subplot(111, projection='3d')

scatter = ax.scatter(X, Y, Z, c=Z, cmap='viridis')

ax.set_xlabel('Time (Ordinal)')
ax.set_ylabel('Logger ID (Numeric)')
ax.set_zlabel('Temperature (°C)')
ax.set_title('3D Plot of Temperatures from All Loggers Over Time')

cbar = fig.colorbar(scatter, ax=ax, orientation='vertical')
cbar.set_label('Temperature (°C)')

ax.view_init(elev=30, azim=120)

plt.show()

# %% [markdown]
# ### Subtraction of environmental data from logger data to account for weather variations.
#
# New columns are added to the master DataFrame for each logger, containing the difference between the logger temperature and the environmental temperature. This subtraction helps to account for weather variations and provides a clearer picture of the indoor temperature changes. The columns would include:
#
# - Temperature difference (Logger temp - Environmental temp)
# - Time period flag (Baseline, Transition, Post-intervention)
#
# Produces `temperature_differences.csv` and `logger_flags.csv` files:

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('master_dataframe.csv', index_col='DateTime', parse_dates=True)

logger_columns = [col for col in df.columns if col != 'Env_Temperature']

diff_df = pd.DataFrame(index=df.index)

for col in logger_columns:
    diff_df[col] = np.where(df[col].notna(), df[col] - df['Env_Temperature'], np.nan)

diff_df.to_csv('temperature_differences.csv')

print("Temperature differences saved to 'temperature_differences.csv'")

# %%
import pandas as pd
import numpy as np

df = pd.read_csv('master_dataframe.csv', index_col='DateTime', parse_dates=True)

logger_columns = [col for col in df.columns if col != 'Env_Temperature']

rainbow_field_loggers = ['U-15', 'U-14', 'U-13', 'U-12', 'U-11', 'U-09', 'U-08', 'U-06', 'U-05', 'U-04', 'U-03', 'R-14', 'R-13', 'R-12', 'R-11', 'R-10', 'R-09']
sports_complex_loggers = ['U-38', 'U-37', 'U-36', 'U-35', 'U-34', 'U-33', 'U-32', 'U-31', 'U-29', 'U-28', 'U-25', 'U-23', 'U-22', 'U-21', 'U-20', 'U-19', 'U-18', 'U-17', 'U-16', 'R-18', 'R-17', 'R-16', 'R-15', 'R-08', 'R-07', 'R-06', 'R-05', 'R-04', 'R-03', 'R-02', 'R-01']

shaded_loggers = ['U-13', 'U-05', 'U-03', 'R-13', 'R-10', 'U-38', 'U-37', 'U-36', 'U-35', 'U-34', 'U-33', 'U-32', 'U-31', 'U-23', 'U-22', 'U-21', 'U-20', 'U-19', 'U-17', 'R-18', 'R-16', 'R-15', 'R-04']
unshaded_loggers = ['U-15', 'U-14', 'U-12', 'U-11', 'U-09', 'U-08', 'U-06', 'U-04', 'R-14', 'R-12', 'R-11', 'R-09', 'U-29', 'U-28', 'U-25', 'U-18', 'U-16', 'R-17', 'R-08', 'R-07', 'R-06', 'R-05', 'R-03', 'R-02', 'R-01']
meb_interventions = ['U-12', 'U-08', 'U-06', 'U-05', 'U-04', 'U-31', 'U-29', 'U-28', 'U-25', 'U-21', 'U-20', 'U-19']
rbf_interventions = ['U-15', 'U-14', 'U-13', 'U-11', 'U-09', 'U-03', 'U-38', 'U-37', 'U-36', 'U-33', 'U-32', 'U-23', 'U-22', 'U-18', 'U-17', 'U-16', 'R-03']
control_interventions = ['R-14', 'R-13', 'R-12', 'R-11', 'R-10', 'R-09', 'U-35', 'U-34', 'R-18', 'R-17', 'R-16', 'R-15', 'R-08', 'R-07', 'R-06', 'R-05', 'R-04', 'R-02', 'R-01']

flags_df = pd.DataFrame(index=logger_columns)
flags_df.index.name = 'Loggers'

flags_df['Shaded'] = flags_df.index.isin(shaded_loggers)
flags_df['Unshaded'] = flags_df.index.isin(unshaded_loggers)
flags_df['Settlement'] = np.where(flags_df.index.isin(rainbow_field_loggers), 'Rainbow Field', 'Sports Complex')
flags_df['Intervention'] = np.select(
    [flags_df.index.isin(meb_interventions), flags_df.index.isin(rbf_interventions), flags_df.index.isin(control_interventions)],
    ['MEB', 'RBF', 'CONTROL'],
    default='Unknown'
)
flags_df['Logger_Type'] = ['U' if logger.startswith('U') else 'R' for logger in flags_df.index]

flags_df['Baseline_Start'] = '2024-06-04'
flags_df['Intervention_Start'] = np.where(flags_df['Settlement'] == 'Rainbow Field', '2024-07-16', '2024-07-20')
flags_df['Post_Intervention_End'] = '2024-08-06'

flags_df.to_csv('logger_flags.csv')

print("Logger flags saved to 'logger_flags.csv'")

# %% [markdown]
# ### Further plans for analyzing the data and evaluating the cooling interventions:
#
# 1. **Handle missing data and outliers:**
#    - Identify and flag any gaps in data recording.
#    - Use statistical methods (e.g., Z-score) to identify and handle outliers.
#
# 2. **Baseline Analysis:**
#
#    a) Analyze pre-intervention period (June 4 to July 14):
#       - Calculate daily average, min, and max temperatures for each logger.
#       - Calculate the standard deviation of temperatures for each logger.
#       - Compare shaded vs. non-shaded structures.
#       - Assess differences between settlements.
#
#    b) Establish baseline patterns:
#       - Analyze diurnal temperature variations.
#       - Identify any pre-existing differences between future intervention groups.
#
# 3. **Intervention Analysis:**
#
#    a) Rainbow Field Settlement (July 16 onwards):
#       - Calculate daily average, min, and max temperatures post-intervention.
#       - Compare MEB, RBF, and control groups.
#       - Analyze the effect of shading within each intervention group.
#
#    b) Sports Complex Settlement (July 20 onwards):
#       - Perform similar analysis as above.
#       - Compare results with Rainbow Field Settlement.
#
# 4. **Comparative Analysis:**
#
#    a) Before-After comparison:
#       - Calculate temperature reduction for each logger (compare average temps before and after intervention).
#       - Analyze the effectiveness of each intervention type (MEB vs. RBF vs. Control).
#
#    b) Shaded vs. Non-shaded comparison:
#       - Compare the effectiveness of interventions in shaded and non-shaded structures.
#
#    c) Settlement comparison:
#       - Analyze if the effectiveness of interventions differs between the two settlements.
#
# 5. **Environmental Adjustment Analysis:**
#
#    a) Temperature difference analysis:
#       - Use the calculated temperature difference (Logger temp - Environmental temp) for all analyses.
#       - This helps account for the cooling effect of rain and other environmental factors.
#
#    b) Precipitation impact:
#       - Analyze how interventions perform during dry vs. rainy periods.
#       - Use environmental data to identify rainy days and assess their impact on intervention effectiveness.
#
# 6. **Statistical Testing and Modeling:**
#
#    a) Hypothesis testing:
#       - Conduct t-tests or ANOVA to compare mean temperatures between intervention groups.
#       - Perform paired t-tests to compare before and after temperatures for each intervention.
#
#    b) Regression analysis:
#       - Develop multiple regression models to predict indoor temperature based on intervention type, shading, environmental factors, etc.
#       - Use time series analysis techniques to account for temporal autocorrelation.
#
# 7. **Visualization and Reporting:**
#
#    a) Create time series plots:
#       - Show temperature trends for different intervention groups over time.
#       - Highlight the baseline, transition, and post-intervention periods.
#
#    b) Box plots and violin plots:
#       - Visualize the distribution of temperatures for different interventions and shading conditions.
#
#    c) Heatmaps:
#       - Create 2D heatmaps showing temperature variations over time for different loggers.
#
#    d) Summary tables:
#       - Create tables summarizing key statistics for each intervention type, shading condition, and settlement.
#
#    e) Final report:
#       - Compile all findings into a comprehensive report, including methodology, results, and recommendations for the most effective cooling interventions.

# %% [markdown]
# # Analyzing Baseline Data for Cooling Interventions in Informal Settlements
#
#
# 1. Calculate the maximum, minimum, and average temperature values for each logger during the baseline period before any cooling interventions were applied.
# 2. Focus the analysis on 'U' loggers to ensure baseline consistency.
# 3. Compute the overall mean of the maximum and minimum temperatures across all relevant loggers.
#
# - **Baseline Period Identification:** For each logger, the baseline period is defined as the time between the start of data recording and the beginning of the intervention. This period varies for different loggers and is extracted from `logger_flags.csv`.
# - **Data Cleaning:** The temperature data for each logger is filtered to remove any NaN or zero values that might distort the analysis.
# - **Summary Statistics:** The maximum, minimum, and average temperature values are calculated for each logger, and overall means are computed across all loggers.
#
# The analysis will produce:
# - A table displaying the maximum, minimum, and average temperatures for each logger.
# - A summary of the mean maximum and minimum temperatures across all U loggers.
# - The table will be saved as a CSV file for further analysis and reporting.
#
# Produces `baseline_temperature_analysis_combined.csv` file:

# %%
import pandas as pd
import numpy as np

master_df = pd.read_csv('master_dataframe.csv', parse_dates=['DateTime'])
temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
logger_flags_df = pd.read_csv('logger_flags.csv')

master_max_values = []
master_min_values = []
master_average_values = []

temp_diff_max_values = []
temp_diff_min_values = []
temp_diff_average_values = []

logger_names = []
settlements = []
shaded = []
interventions = []

u_loggers = logger_flags_df[logger_flags_df['Loggers'].str.startswith('U')]

for _, row in u_loggers.iterrows():
    logger = row['Loggers']
    baseline_start = pd.to_datetime(row['Baseline_Start'])
    intervention_start = pd.to_datetime(row['Intervention_Start'])

    master_baseline_data = master_df[(master_df['DateTime'] >= baseline_start) & 
                                     (master_df['DateTime'] < intervention_start)][logger]
    
    temp_diff_baseline_data = temperature_differences_df[(temperature_differences_df['DateTime'] >= baseline_start) & 
                                                         (temperature_differences_df['DateTime'] < intervention_start)][logger]

    valid_master_data = master_baseline_data[(~master_baseline_data.isna()) & (master_baseline_data != 0)]
    valid_temp_diff_data = temp_diff_baseline_data[(~temp_diff_baseline_data.isna()) & (temp_diff_baseline_data != 0)]

    master_max_value = valid_master_data.max()
    master_min_value = valid_master_data.min()
    master_average_value = valid_master_data.mean()

    temp_diff_max_value = valid_temp_diff_data.max()
    temp_diff_min_value = valid_temp_diff_data.min()
    temp_diff_average_value = valid_temp_diff_data.mean()

    master_max_values.append(master_max_value)
    master_min_values.append(master_min_value)
    master_average_values.append(master_average_value)

    temp_diff_max_values.append(temp_diff_max_value)
    temp_diff_min_values.append(temp_diff_min_value)
    temp_diff_average_values.append(temp_diff_average_value)

    logger_names.append(logger)
    settlements.append(row['Settlement'])
    shaded.append(row['Shaded'])
    interventions.append(row['Intervention'])

results_df = pd.DataFrame({
    'Logger': logger_names,
    'Settlement': settlements,
    'Shaded': shaded,
    'Intervention Type': interventions,
    'Master Max Temperature': master_max_values,
    'Master Min Temperature': master_min_values,
    'Master Average Temperature': master_average_values,
    'Temp Diff Max Temperature': temp_diff_max_values,
    'Temp Diff Min Temperature': temp_diff_min_values,
    'Temp Diff Average Temperature': temp_diff_average_values,
})

print("\nTable of Results:")
print(results_df)

results_df.to_csv('baseline_temperature_analysis_combined.csv', index=False)

# %% [markdown]
# ### This script will calculate the daily averages and standard deviations for both day and night separately, using the temperature differences data.
#
# - **Day/Night Segmentation:** The data is split into day and night periods based on specific time ranges (6 AM to 7 PM for the time period during summer).
# - **Statistical Calculations:** For each day, the average and standard deviation of temperature differences are computed separately for day and night.
# - **Rain Detection:** Rain data from the environmental file is used to flag whether it rained on each day.
# - **CSV Output:** The final results, including calculated statistics and rain data, are saved in a new CSV file.
#
# Produces `daily_temperature_metrics.csv` file:

# %%
import pandas as pd
import numpy as np

temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
environmental_data_df = pd.read_csv('Environmental Data.csv', parse_dates=[['Date', 'Time']])

day_start = '06:00:00'
day_end = '19:00:00'

# Function to check if it rained during the day
def did_it_rain(date):
    rain_data = environmental_data_df[
        (environmental_data_df['Date_Time'].dt.date == date) & 
        (environmental_data_df['preciptype'].notna())
    ]
    return not rain_data.empty

data = []

for date in temperature_differences_df['DateTime'].dt.date.unique():
    day_data = {}
    
    day_mask = (temperature_differences_df['DateTime'].dt.date == date) & \
               (temperature_differences_df['DateTime'].dt.time >= pd.to_datetime(day_start).time()) & \
               (temperature_differences_df['DateTime'].dt.time < pd.to_datetime(day_end).time())
               
    night_mask = (temperature_differences_df['DateTime'].dt.date == date) & \
                 ((temperature_differences_df['DateTime'].dt.time < pd.to_datetime(day_start).time()) | \
                 (temperature_differences_df['DateTime'].dt.time >= pd.to_datetime(day_end).time()))
    
    day_temps = temperature_differences_df[day_mask]
    night_temps = temperature_differences_df[night_mask]
    
    for logger in temperature_differences_df.columns[1:]:
        day_temps_logger = day_temps[logger].dropna()
        night_temps_logger = night_temps[logger].dropna()
        
        day_data[f'{logger}_day_avg'] = day_temps_logger.mean()
        day_data[f'{logger}_day_std'] = day_temps_logger.std()
        day_data[f'{logger}_day_min'] = day_temps_logger.min()
        day_data[f'{logger}_day_max'] = day_temps_logger.max()
        
        day_data[f'{logger}_night_avg'] = night_temps_logger.mean()
        day_data[f'{logger}_night_std'] = night_temps_logger.std()
        day_data[f'{logger}_night_min'] = night_temps_logger.min()
        day_data[f'{logger}_night_max'] = night_temps_logger.max()
    
    # Determine if it rained that day
    day_data['Date'] = date
    day_data['Rain'] = did_it_rain(date)
    
    data.append(day_data)

daily_metrics_df = pd.DataFrame(data)

final_columns = ['Date', 'Rain'] + [col for col in daily_metrics_df.columns if col not in ['Date', 'Rain']]
daily_metrics_df = daily_metrics_df[final_columns]

daily_metrics_df.to_csv('daily_temperature_metrics.csv', index=False)

# %% [markdown]
# ### Analyzing Intervention Period Data for Cooling Interventions
#
# This analyzes the temperature data from all loggers during the intervention period, based on the `Intervention_Start` and `Post_Intervention_End` dates. The analysis includes both the raw temperature data (`master_dataframe.csv`) and the adjusted temperature data (`temperature_differences.csv`).
#
# - Calculates the maximum, minimum, and average temperatures for each logger during the intervention period.
# - Include the logger's metadata (Settlement, Shaded, and Intervention Type) in the results.
#
# Produces `intervention_temperature_analysis_combined.csv` file:

# %%
import pandas as pd
import numpy as np

master_df = pd.read_csv('master_dataframe.csv', parse_dates=['DateTime'])
temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
logger_flags_df = pd.read_csv('logger_flags.csv')

master_max_values = []
master_min_values = []
master_average_values = []

temp_diff_max_values = []
temp_diff_min_values = []
temp_diff_average_values = []

logger_names = []
settlements = []
shaded = []
interventions = []

for _, row in logger_flags_df.iterrows():
    logger = row['Loggers']
    intervention_start = pd.to_datetime(row['Intervention_Start'])
    post_intervention_end = pd.to_datetime(row['Post_Intervention_End'])
    
    master_intervention_data = master_df[(master_df['DateTime'] >= intervention_start) & 
                                         (master_df['DateTime'] <= post_intervention_end)][logger]
    
    temp_diff_intervention_data = temperature_differences_df[(temperature_differences_df['DateTime'] >= intervention_start) & 
                                                             (temperature_differences_df['DateTime'] <= post_intervention_end)][logger]

    valid_master_data = master_intervention_data[(~master_intervention_data.isna()) & (master_intervention_data != 0)]
    valid_temp_diff_data = temp_diff_intervention_data[(~temp_diff_intervention_data.isna()) & (temp_diff_intervention_data != 0)]

    master_max_value = valid_master_data.max()
    master_min_value = valid_master_data.min()
    master_average_value = valid_master_data.mean()

    temp_diff_max_value = valid_temp_diff_data.max()
    temp_diff_min_value = valid_temp_diff_data.min()
    temp_diff_average_value = valid_temp_diff_data.mean()

    master_max_values.append(master_max_value)
    master_min_values.append(master_min_value)
    master_average_values.append(master_average_value)

    temp_diff_max_values.append(temp_diff_max_value)
    temp_diff_min_values.append(temp_diff_min_value)
    temp_diff_average_values.append(temp_diff_average_value)

    logger_names.append(logger)
    settlements.append(row['Settlement'])
    shaded.append(row['Shaded'])
    interventions.append(row['Intervention'])

results_df = pd.DataFrame({
    'Logger': logger_names,
    'Settlement': settlements,
    'Shaded': shaded,
    'Intervention Type': interventions,
    'Master Max Temperature': master_max_values,
    'Master Min Temperature': master_min_values,
    'Master Average Temperature': master_average_values,
    'Temp Diff Max Temperature': temp_diff_max_values,
    'Temp Diff Min Temperature': temp_diff_min_values,
    'Temp Diff Average Temperature': temp_diff_average_values,
})

# Print out the results
print("\nTable of Results:")
print(results_df)

# Save the results to a CSV file
results_df.to_csv('intervention_temperature_analysis_combined.csv', index=False)

# %% [markdown]
# # Plotting Temperature Differences for Cooling Interventions
#
# - It generates line plots for temperature differences across various loggers during the intervention periods in different settlements.
# - It includes plots for both the Rainbow Field and Sports Complex, with color-coded lines indicating different loggers.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import numpy as np

temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
logger_flags_df = pd.read_csv('logger_flags.csv')

shaded_base_color = mcolors.CSS4_COLORS['darkblue']
unshaded_base_color = mcolors.CSS4_COLORS['lightblue']

def get_shades(base_color, num_shades):
    return [mcolors.to_rgba(base_color, alpha) for alpha in np.linspace(0.3, 1, num_shades)]

def plot_temperature_differences(settlement, intervention_type, title, multi_label=False):
    loggers_subset = logger_flags_df[(logger_flags_df['Settlement'] == settlement) & 
                                     (logger_flags_df['Intervention'] == intervention_type)]
    
    num_loggers = len(loggers_subset)
    shaded_loggers = loggers_subset[loggers_subset['Shaded']]
    unshaded_loggers = loggers_subset[~loggers_subset['Shaded']]

    shaded_colors = get_shades(shaded_base_color, len(shaded_loggers))
    unshaded_colors = get_shades(unshaded_base_color, len(unshaded_loggers))
    
    fig, ax = plt.subplots(figsize=(14, 8))
    lines = []
    
    for idx, (_, row) in enumerate(shaded_loggers.iterrows()):
        logger = row['Loggers']
        intervention_start = pd.to_datetime(row['Intervention_Start'])
        post_intervention_end = pd.to_datetime(row['Post_Intervention_End'])
        
        line, = ax.plot(temperature_differences_df['DateTime'], temperature_differences_df[logger], 
                        label=f"{logger} (Shaded)", color=shaded_colors[idx], linewidth=2)
        lines.append(line)

    for idx, (_, row) in enumerate(unshaded_loggers.iterrows()):
        logger = row['Loggers']
        intervention_start = pd.to_datetime(row['Intervention_Start'])
        post_intervention_end = pd.to_datetime(row['Post_Intervention_End'])
        
        line, = ax.plot(temperature_differences_df['DateTime'], temperature_differences_df[logger], 
                        label=f"{logger} (Unshaded)", color=unshaded_colors[idx], linewidth=2)
        lines.append(line)

    ax.axvline(x=intervention_start, color='red', linestyle='--', linewidth=1)
    ax.text(intervention_start, ax.get_ylim()[1], 'Intervention Start', color='red', verticalalignment='top')

    if multi_label:
        intervention_mid = intervention_start + pd.Timedelta(days=2)
        ax.axvline(x=intervention_mid, color='orange', linestyle='--', linewidth=1)
        ax.text(intervention_mid, ax.get_ylim()[1], 'Intervention Implemented', color='orange', verticalalignment='top')
        
        ax.axvline(x=post_intervention_end, color='green', linestyle='--', linewidth=1)
        ax.text(post_intervention_end, ax.get_ylim()[1], 'Intervention End', color='green', verticalalignment='top')
    
    ax.set_title(title)
    ax.set_xlabel('DateTime')
    ax.set_ylabel('Temperature Difference (°C)')
    leg = ax.legend(loc='upper right', fancybox=True, shadow=True)
    leg.get_frame().set_alpha(0.4)

    lined = dict()
    for legline, origline in zip(leg.get_lines(), lines):
        legline.set_picker(5)  # 5 pts tolerance
        lined[legline] = origline

    def onpick(event):
        legline = event.artist
        origline = lined[legline]
        vis = not origline.get_visible()
        origline.set_visible(vis)
        legline.set_alpha(1.0 if vis else 0.2)
        fig.canvas.draw()

    fig.canvas.mpl_connect('pick_event', onpick)

    plt.grid(True)
    plt.show()

plot_temperature_differences('Rainbow Field', 'RBF', 'Rainbow Field - RBF Intervention')
plot_temperature_differences('Rainbow Field', 'MEB', 'Rainbow Field - MEB Intervention')
plot_temperature_differences('Rainbow Field', 'CONTROL', 'Rainbow Field - Control Loggers')
plot_temperature_differences('Sports Complex', 'RBF', 'Sports Complex - RBF Intervention', multi_label=True)
plot_temperature_differences('Sports Complex', 'MEB', 'Sports Complex - MEB Intervention', multi_label=True)
plot_temperature_differences('Sports Complex', 'CONTROL', 'Sports Complex - Control Loggers', multi_label=True)

# %% [markdown]
# ### Statistical analysis for the intervention in any settlement.
#
# This script performs several statistical analyses to evaluate the impact of an intervention in a specific settlement. The analyses include:
#
# 1. **Wilcoxon Signed-Rank Test:** Assesses if there is a significant difference in temperature reductions between the pre- and post-intervention periods. A non-parametric test to determine if the median temperature reductions are significantly different.
# 2. **Effect Size Measurements:**
#    - **Cohen's d:** Measures the standardized mean difference between pre- and post-intervention temperatures.
#    - **Cliff's Delta:** A non-parametric effect size measure.
# 3. **OLS Regression Analysis:** Evaluates the relationship between the intervention period and temperature differences.
# 4. **ANOVA:** Tests for significant differences in temperature reductions.
# 5. **P-value Hypothesis Test**: To test whether the temperature reduction after the intervention is statistically significant compared to the control.
#
# ### **Hypothesis for the P-value Test:**
#
# - **Null Hypothesis (H0)**: The intervention does not result in a statistically significant reduction in temperature compared to the control (no intervention).
# - **Alternative Hypothesis (H1)**: The intervention results in a statistically significant reduction in temperature compared to the control.

# %%
import pandas as pd
import numpy as np
import statsmodels.api as sm
from statsmodels.formula.api import ols
from scipy.stats import wilcoxon
from scipy import stats

temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
logger_flags_df = pd.read_csv('logger_flags.csv')

settlement = 'Sports Complex'
intervention_type = 'RBF'
shaded = False

loggers_subset = logger_flags_df[
                                (logger_flags_df['Settlement'] == settlement) 
                                & (logger_flags_df['Intervention'] == intervention_type) 
                                # Uncomment the line below to filter by shaded/unshaded loggers
                                # & (logger_flags_df['Shaded'] == shaded)
                                ]

pre_intervention_data = []
post_intervention_data = []

for _, row in loggers_subset.iterrows():
    logger = row['Loggers']
    intervention_start = pd.to_datetime(row['Intervention_Start'])
    
    # Pre-intervention data (before intervention)
    pre_data = temperature_differences_df[(temperature_differences_df['DateTime'] < intervention_start)][logger]
    pre_intervention_data.extend(pre_data.dropna().tolist())

    # Post-intervention data (after intervention)
    post_data = temperature_differences_df[(temperature_differences_df['DateTime'] >= intervention_start)][logger]
    post_intervention_data.extend(post_data.dropna().tolist())

# Ensure both datasets are the same length
min_length = min(len(pre_intervention_data), len(post_intervention_data))
pre_intervention_data = pre_intervention_data[:min_length]
post_intervention_data = post_intervention_data[:min_length]

pre_data_series = np.array(pre_intervention_data)
post_data_series = np.array(post_intervention_data)

# Wilcoxon signed-rank test
w_statistic, p_value = wilcoxon(post_data_series, pre_data_series)
print(f"Wilcoxon signed-rank test statistic: {w_statistic}, p-value: {p_value}")

# Hypothesis for p-value test
# Null hypothesis (H0): There is no significant difference in temperature reductions.
# Alternative hypothesis (H1): There is a significant difference in temperature reductions.
alpha = 0.05
if p_value < alpha:
    print("\nNull hypothesis rejected: There is a significant difference in temperature reductions.")
else:
    print("\nNull hypothesis accepted: There is no significant difference in temperature reductions.")

mean_diff = np.mean(post_data_series - pre_data_series)
std_diff = np.std(post_data_series - pre_data_series, ddof=1)

# Calculate Cliff's delta
def cliff_delta(a, b):
    """
    Calculate Cliff's Delta for non-parametric effect size.
    """
    a = np.array(a)
    b = np.array(b)
    n1 = len(a)
    n2 = len(b)
    combined = np.concatenate([a, b])
    n1_over_n2 = 0
    for i in range(n1):
        n1_over_n2 += np.sum(combined[i] > combined[n1:])
    return (n1_over_n2 - (n1 * n2 / 2)) / (n1 * n2)

cliffs_delta = cliff_delta(pre_data_series, post_data_series)
print(f"\nCliff's delta: {cliffs_delta}")

# OLS Regression
df = pd.DataFrame({
    'TemperatureDifference': np.concatenate([pre_data_series, post_data_series]),
    'InterventionPeriod': ['Pre']*len(pre_data_series) + ['Post']*len(post_data_series)
})

model = ols('TemperatureDifference ~ C(InterventionPeriod)', data=df).fit()

print("\n\nOLS Regression Results:")
print(model.summary())

# Perform ANOVA
anova_table = sm.stats.anova_lm(model, typ=2)
print("\n\nANOVA Results:")
print(anova_table)

# %% [markdown]
# ### Temperature Reduction Calculation for Intervention Sites
#
# This script calculates and prints the average temperature reductions before and after cooling interventions for different settlements.
#
# 1. **Temperature Data Processing**:
#    - Pre- and post-intervention temperature data are extracted for loggers in selected settlements.
#    - Data can be filtered for daytime-only measurements (6 AM to 7 PM).
#    - Comparisons can be made either with or without control loggers.
# 3. **Shaded and Unshaded Loggers**: The script provides the option to calculate temperature reductions for shaded, unshaded, or all loggers.
# 4. **Comparison with Control Loggers**: Optionally, the script compares temperature reductions against control loggers.
# 4. **Temperature Reduction Results**: The calculated temperature reductions are printed for each scenario (with or without controls, daytime only, etc.).
#
# The function outputs the average temperature reductions in Celsius for each intervention type across both settlements. Higher reductions indicate more effective cooling interventions. Negative values indicate an increase in temperature.

# %%
import pandas as pd
import numpy as np

def calculate_temperature_reduction(settlement, intervention_type, shaded=None, daytime_only=False, compare_with_control=False):
    temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
    logger_flags_df = pd.read_csv('logger_flags.csv')

    loggers_subset = logger_flags_df[
        (logger_flags_df['Settlement'] == settlement) &
        (logger_flags_df['Intervention'] == intervention_type)
    ]
    
    if shaded is not None:
        loggers_subset = loggers_subset[loggers_subset['Shaded'] == shaded]

    pre_intervention_data = []
    post_intervention_data = []
    control_data = []

    for _, row in loggers_subset.iterrows():
        logger = row['Loggers']
        intervention_start = pd.to_datetime(row['Intervention_Start'])
        
        if daytime_only:
            mask = (temperature_differences_df['DateTime'].dt.hour >= 6) & (temperature_differences_df['DateTime'].dt.hour < 19)
            temperature_differences_df = temperature_differences_df[mask]

        if compare_with_control:
            control_loggers = logger_flags_df[(logger_flags_df['Settlement'] == settlement) & (logger_flags_df['Intervention'] == 'CONTROL')]
            for _, control_row in control_loggers.iterrows():
                control_logger = control_row['Loggers']
                control_data.extend(temperature_differences_df[control_logger].dropna().tolist())
        else:
            pre_data = temperature_differences_df[temperature_differences_df['DateTime'] < intervention_start][logger]
            pre_intervention_data.extend(pre_data.dropna().tolist())

        post_data = temperature_differences_df[temperature_differences_df['DateTime'] >= intervention_start][logger]
        post_intervention_data.extend(post_data.dropna().tolist())

    if compare_with_control:
        avg_control_temperature = np.mean(control_data)
        avg_post_temperature = np.mean(post_intervention_data)
        avg_temperature_reduction = avg_control_temperature - avg_post_temperature
    else:
        min_length = min(len(pre_intervention_data), len(post_intervention_data))
        pre_intervention_data = pre_intervention_data[:min_length]
        post_intervention_data = post_intervention_data[:min_length]

        avg_pre_temperature = np.mean(pre_intervention_data)
        avg_post_temperature = np.mean(post_intervention_data)
        avg_temperature_reduction = avg_pre_temperature - avg_post_temperature
    
    return avg_temperature_reduction

def print_temperature_reductions(daytime_only=False, compare_with_control=False):
    settlements = ['Rainbow Field', 'Sports Complex']
    interventions = ['MEB', 'RBF']
    shading = [None, True, False]

    print(f"{'Daytime Only' if daytime_only else 'All Day'} Temperature Reductions {'(Compared to Control)' if compare_with_control else ''}:")
    print("=" * 80)

    for settlement in settlements:
        print(f"\n{settlement}:")
        for intervention in interventions:
            for shade in shading:
                shade_str = "Shaded" if shade == True else "Unshaded" if shade == False else "All"
                reduction = calculate_temperature_reduction(settlement, intervention, shaded=shade, daytime_only=daytime_only, compare_with_control=compare_with_control)
                print(f"  {intervention} ({shade_str}): {reduction:.2f}°C")

# Print results for all scenarios
print_temperature_reductions()
print("\n")
print_temperature_reductions(daytime_only=True)
print("\n")
print_temperature_reductions(compare_with_control=True)
print("\n")
print_temperature_reductions(daytime_only=True, compare_with_control=True)

# %% [markdown]
# ### Calculating Temperature Reduction Via Peaks
#
# This script analyzes the temperature reductions by evaluating both peak and overall temperature changes. It calculates the reduction in peak temperatures using the 95th percentile and compares the overall temperature distributions before and after interventions.
#
# 1. **Peak Temperature Reduction**: Calculates the reduction in peak temperatures using the 95th percentile, focusing on the extreme heat reduction impact.
# 2. **Kolmogorov-Smirnov Test**: Compares the overall temperature distributions before and after interventions (or between intervention and control loggers), reporting a p-value to determine the statistical significance of the changes.
# 3. **Flexible Filtering**: The analysis can be filtered for:
#    - Shaded or unshaded loggers.
#    - Daytime-only (6 AM - 7 PM) temperature data.
#    - Comparison with control loggers instead of pre-intervention data.

# %%
import pandas as pd
import numpy as np
from scipy import stats

def calculate_temperature_reduction(settlement, intervention_type, shaded=None, daytime_only=False, compare_with_control=False):
    temperature_differences_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
    logger_flags_df = pd.read_csv('logger_flags.csv')

    loggers_subset = logger_flags_df[
        (logger_flags_df['Settlement'] == settlement) &
        (logger_flags_df['Intervention'] == intervention_type)
    ]
    
    if shaded is not None:
        loggers_subset = loggers_subset[loggers_subset['Shaded'] == shaded]

    pre_intervention_data = []
    post_intervention_data = []
    control_data = []

    for _, row in loggers_subset.iterrows():
        logger = row['Loggers']
        intervention_start = pd.to_datetime(row['Intervention_Start'])
        
        if daytime_only:
            mask = (temperature_differences_df['DateTime'].dt.hour >= 6) & (temperature_differences_df['DateTime'].dt.hour < 19)
            temperature_differences_df = temperature_differences_df[mask]

        if compare_with_control:
            control_loggers = logger_flags_df[(logger_flags_df['Settlement'] == settlement) & (logger_flags_df['Intervention'] == 'CONTROL')]
            for _, control_row in control_loggers.iterrows():
                control_logger = control_row['Loggers']
                control_data.extend(temperature_differences_df[control_logger].dropna().tolist())
        else:
            pre_data = temperature_differences_df[temperature_differences_df['DateTime'] < intervention_start][logger]
            pre_intervention_data.extend(pre_data.dropna().tolist())

        post_data = temperature_differences_df[temperature_differences_df['DateTime'] >= intervention_start][logger]
        post_intervention_data.extend(post_data.dropna().tolist())

    if compare_with_control:
        control_data = np.array(control_data)
        post_intervention_data = np.array(post_intervention_data)
    else:
        pre_intervention_data = np.array(pre_intervention_data)
        post_intervention_data = np.array(post_intervention_data)

    # Calculate peak reduction (95th percentile)
    if compare_with_control:
        peak_reduction = np.percentile(control_data, 95) - np.percentile(post_intervention_data, 95)
    else:
        peak_reduction = np.percentile(pre_intervention_data, 95) - np.percentile(post_intervention_data, 95)

    # Calculate overall distribution change
    if compare_with_control:
        _, p_value = stats.ks_2samp(control_data, post_intervention_data)
        distribution_change = np.mean(control_data) - np.mean(post_intervention_data)
    else:
        _, p_value = stats.ks_2samp(pre_intervention_data, post_intervention_data)
        distribution_change = np.mean(pre_intervention_data) - np.mean(post_intervention_data)

    return peak_reduction, distribution_change, p_value

def print_temperature_reductions(daytime_only=False, compare_with_control=False):
    settlements = ['Rainbow Field', 'Sports Complex']
    interventions = ['MEB', 'RBF']
    shading = [None, True, False]

    print(f"{'Daytime Only' if daytime_only else 'All Day'} Temperature Reductions {'(Compared to Control)' if compare_with_control else ''}:")
    print("=" * 100)

    for settlement in settlements:
        print(f"\n{settlement}:")
        for intervention in interventions:
            for shade in shading:
                shade_str = "Shaded" if shade == True else "Unshaded" if shade == False else "All"
                peak_reduction, distribution_change, p_value = calculate_temperature_reduction(
                    settlement, intervention, shaded=shade, daytime_only=daytime_only, compare_with_control=compare_with_control
                )
                print(f"  {intervention} ({shade_str}):")
                print(f"    Peak Reduction (95th percentile): {peak_reduction:.2f}°C")
                print(f"    Overall Distribution Change: {distribution_change:.2f}°C")
                print(f"    P-value (Kolmogorov-Smirnov test): {p_value:.4f}")

# Print results for all scenarios
print_temperature_reductions()
print("\n")
print_temperature_reductions(daytime_only=True)
print("\n")
print_temperature_reductions(compare_with_control=True)
print("\n")
print_temperature_reductions(daytime_only=True, compare_with_control=True)

# %% [markdown]
# ### Heat Wave and Thermal Comfort Analysis
#
# This script focuses on:
#
# 1. Calculating heat index based on temperature and humidity data.
# 2. Identifying heat wave occurrences using Indian Meteorological Department criteria.
# 3. Assessing changes in thermal comfort levels before and after interventions.
# 4. Comparing intervention effects between different settlements, shading conditions, and control groups.
#
# The script processes data from multiple temperature loggers, environmental data, and logger metadata to produce comprehensive results on heat wave frequency and comfort level changes.

# %%
import pandas as pd
import numpy as np
from datetime import timedelta
from tabulate import tabulate

def calculate_heat_index(temperature, humidity):
    """Calculate heat index using temperature (°C) and relative humidity (%)."""
    T = temperature * 9/5 + 32
    RH = humidity
    
    HI = -42.379 + 2.04901523*T + 10.14333127*RH - 0.22475541*T*RH - 6.83783e-3*T**2 - 5.481717e-2*RH**2 + 1.22874e-3*T**2*RH + 8.5282e-4*T*RH**2 - 1.99e-6*T**2*RH**2
    
    return (HI - 32) * 5/9

def is_heat_wave(temp, normal_temp):
    """Check if the temperature meets heat wave criteria."""
    departure = temp - normal_temp
    if temp >= 45:
        return 'Severe Heat Wave (Actual)'
    elif temp >= 40:
        if departure > 6.4:
            return 'Severe Heat Wave'
        elif 4.5 <= departure <= 6.4:
            return 'Heat Wave'
    return 'Normal'

master_df = pd.read_csv('master_dataframe.csv', parse_dates=['DateTime'])
temp_diff_df = pd.read_csv('temperature_differences.csv', parse_dates=['DateTime'])
env_df = pd.read_csv('Environmental Data.csv', parse_dates=[['Date', 'Time']])

merged_df = pd.merge_asof(master_df, env_df, left_on='DateTime', right_on='Date_Time')

for logger in [col for col in master_df.columns if col.startswith('U-') or col.startswith('R-')]:
    logger_file = f'Cleaned Data/{logger}_data.csv'
    try:
        logger_df = pd.read_csv(logger_file, parse_dates=[['Date', 'Time']])
        
        if 'Relative_Humidity(%)' in logger_df.columns:
            humidity_col = 'Relative_Humidity(%)'
        elif 'Humidity(%RH)' in logger_df.columns:
            humidity_col = 'Humidity(%RH)'
        else:
            print(f"Humidity column not found for {logger}")
            continue
        
        temp_col = 'Temperature_Celsius(℃)' if 'Temperature_Celsius(℃)' in logger_df.columns else 'Temperature(C)'
        
        logger_df['Heat_Index'] = logger_df.apply(lambda row: calculate_heat_index(row[temp_col], row[humidity_col]), axis=1)
        
        merged_df = pd.merge_asof(merged_df, logger_df[['Date_Time', 'Heat_Index']], left_on='DateTime', right_on='Date_Time', suffixes=('', f'_{logger}'))
        merged_df.rename(columns={'Heat_Index': f'{logger}_Heat_Index'}, inplace=True)
    except FileNotFoundError:
        print(f"File not found for {logger}")
    except Exception as e:
        print(f"Error processing {logger}: {str(e)}")

merged_df['Env_Heat_Wave'] = merged_df.apply(lambda row: is_heat_wave(row['temp'], row['temp'] - row['Env_Temperature']), axis=1)

for logger in [col for col in master_df.columns if col.startswith('U-') or col.startswith('R-')]:
    if logger in merged_df.columns:
        merged_df[f'{logger}_Heat_Wave'] = merged_df.apply(lambda row: is_heat_wave(row[logger], row['temp']), axis=1)

logger_groups = {
    'Rainbow Field': {
        'RBF': {'Shaded': [], 'Unshaded': []},
        'MEB': {'Shaded': [], 'Unshaded': []},
        'CONTROL': {'Shaded': [], 'Unshaded': []}
    },
    'Sports Complex': {
        'RBF': {'Shaded': [], 'Unshaded': []},
        'MEB': {'Shaded': [], 'Unshaded': []},
        'CONTROL': {'Shaded': [], 'Unshaded': []}
    }
}

for _, row in logger_flags_df.iterrows():
    logger = row['Loggers']
    settlement = row['Settlement']
    intervention = row['Intervention']
    shaded = 'Shaded' if row['Shaded'] else 'Unshaded'
    
    if intervention in ['RBF', 'MEB', 'CONTROL']:
        logger_groups[settlement][intervention][shaded].append(logger)
    else:
        print(f"Skipping logger {logger} due to unknown intervention type: {intervention}")

# Calculate average for a group of loggers
def calculate_group_average(df, loggers, column_suffix):
    return df[[f'{logger}{column_suffix}' for logger in loggers if f'{logger}{column_suffix}' in df.columns]].mean(axis=1)

# Calculate heat wave occurrences
heat_wave_results = []
for settlement in logger_groups:
    for intervention in logger_groups[settlement]:
        for shading in logger_groups[settlement][intervention]:
            loggers = logger_groups[settlement][intervention][shading]
            if loggers:
                heat_wave_count = merged_df[[f'{logger}_Heat_Wave' for logger in loggers if f'{logger}_Heat_Wave' in merged_df.columns]].apply(lambda x: (x != 'Normal').sum()).mean()
                heat_wave_results.append([settlement, intervention, shading, heat_wave_count])

# Calculate comfort level changes
comfort_change_results = []
for settlement in logger_groups:
    for intervention in logger_groups[settlement]:
        if intervention != 'CONTROL':
            for shading in logger_groups[settlement][intervention]:
                loggers = logger_groups[settlement][intervention][shading]
                control_loggers = logger_groups[settlement]['CONTROL'][shading]
                
                if loggers and control_loggers:
                    intervention_start = pd.to_datetime(logger_flags_df[logger_flags_df['Loggers'] == loggers[0]]['Intervention_Start'].iloc[0])
                    
                    intervention_pre = calculate_group_average(merged_df[merged_df['DateTime'] < intervention_start], loggers, '_Heat_Index').mean()
                    intervention_post = calculate_group_average(merged_df[merged_df['DateTime'] >= intervention_start], loggers, '_Heat_Index').mean()
                    
                    control_pre = calculate_group_average(merged_df[merged_df['DateTime'] < intervention_start], control_loggers, '_Heat_Index').mean()
                    control_post = calculate_group_average(merged_df[merged_df['DateTime'] >= intervention_start], control_loggers, '_Heat_Index').mean()
                    
                    intervention_change = intervention_pre - intervention_post
                    control_change = control_pre - control_post
                    relative_change = intervention_change - control_change
                    
                    comfort_change_results.append([settlement, intervention, shading, intervention_change, control_change, relative_change])

print("Heat Wave Occurrences:")
print(tabulate(heat_wave_results, headers=['Settlement', 'Intervention', 'Shading', 'Average Heat Wave Count'], tablefmt='grid'))

print("\nComfort Level Changes After Interventions:")
print(tabulate(comfort_change_results, headers=['Settlement', 'Intervention', 'Shading', 'Intervention Change', 'Control Change', 'Relative Change'], tablefmt='grid'))
